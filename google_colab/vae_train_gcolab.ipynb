# %%
from dataclasses import dataclass
import time
import glob
import torch
import numpy as np
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms

import sys
sys.path.append('/content/drive/MyDrive/shunt_stady/va2021')

from src.train.train_vae import process as _process


t_dir_path = '../train/*.png'
e_dir_path = '../test/*.png'


@dataclass
class Config:
    lr: float = 8e-3
    beta1:float = 0.9
    beta2:float = 0.9
    input_dim: int = 16384
    num_epoch: int = 100
    num_stopping: int = 50
    batch_size: int = 64
    z_dim: int = 50
    save_path: str = '/model/vae.pt'


model = _process(t_dir_path, e_dir_path, Config())
# Out:
# Use device： cuda:0
# -------------
# Epoch 0/100
# -------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f37c277e4243> in <module>()
#      32
#      33
# ---> 34 model = _process(t_dir_path, e_dir_path, Config())
#
# /content/drive/My Drive/shunt_stady/va_2021/src/train/train_vae.py in process(train_dir_path, eval_dir_path, config)
#     151
#     152     # train model
# --> 153     model = train(train_dataloader, eval_dataloader, vae)
#     154
#     155     # save model
#
# /content/drive/My Drive/shunt_stady/va_2021/src/train/train_vae.py in train(train_dataloader, eval_dataloader, model, config)
#      54         model.train()
#      55         train_epoch_loss = 0
# ---> 56         for images in train_dataloader:
#      57
#      58             images = images.to(device)
#
# ...

# %%
# %cd /content/drive/MyDrive/shunt_stady/va_2021/
# Out:
# /content/drive/MyDrive/shunt_stady/va_2021

# %%
# !git pull origin master
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# From https://github.com/HirokiFuyama/va_2021
#  * branch            master     -> FETCH_HEAD
#    b7d1252..05a304e  master     -> origin/master
# Updating b7d1252..05a304e
# Fast-forward
#  src/train/train_vae.py | 10 ++++++----
#  1 file changed, 6 insertions(+), 4 deletions(-)
