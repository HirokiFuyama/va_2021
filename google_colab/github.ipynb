# %%
# creat git clone

# %cd /content/drive/MyDrive/shunt_stady/
# ! git clone https://github.com/HirokiFuyama/va_2021.git

# %%
# config
# !git config --global user.email "email"
# !git config --global user.name "username"

# add
# %cd 'file pahe'
! git add 'file name'

# commig
# !git commit -m 'comment'

# push
# !git remote set-url origin https://'username':'pass'@github.com/'username'/va_2021.git
# !git push origin 'branch name'

# git branch , git checkout も普通に使える
